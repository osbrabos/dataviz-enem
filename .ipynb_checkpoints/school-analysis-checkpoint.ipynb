# %% [markdown]
# ## Importação dos dados

# %%
import re
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

# %%
p = 0.01

df = pd.read_csv(
    'MICRODADOS_ENEM_ESCOLA.csv',
    header=0,
    encoding = "ISO-8859-1",
    sep=';',
    dtype={'INSE': 'string'}
)

df
# Out:
#         NU_ANO  CO_UF_ESCOLA SG_UF_ESCOLA  CO_MUNICIPIO_ESCOLA  \
# 0         2007            11           RO              1100205
# 1         2006            11           RO              1100205
# 2         2005            11           RO              1100205
# 3         2008            11           RO              1100205
# 4         2007            11           RO              1100205
# ...        ...           ...          ...                  ...
# 172300    2013            53           DF              5300108
# 172301    2014            53           DF              5300108
# 172302    2015            53           DF              5300108
# 172303    2014            53           DF              5300108
# 172304    2015            53           DF              5300108
#
#        NO_MUNICIPIO_ESCOLA  CO_ESCOLA_EDUCACENSO       NO_ESCOLA_EDUCACENSO  \
# 0              Porto Velho              11000058  CENTRO DE ENSINO CLASSE A
# 1              Porto Velho              11000058  CENTRO DE ENSINO CLASSE A
# 2              Porto Velho              11000058  CENTRO DE ENSINO CLASSE A
# 3              Porto Velho              11000058  CENTRO DE ENSINO CLASSE A
# 4              Porto Velho              11000171  CENTRO EDUCACIONAL MOJUCA
# ...                    ...                   ...                        ...
# 172300            Brasília              53068181     CED 310 DE SANTA MARIA
# 172301            Brasília              53068181     CED 310 DE SANTA MARIA
# 172302            Brasília              53068181     CED 310 DE SANTA MARIA
# 172303            Brasília              53082001                COL IMPACTO
# 172304            Brasília              53082001                COL IMPACTO
#
#         TP_DEPENDENCIA_ADM_ESCOLA  TP_LOCALIZACAO_ESCOLA  NU_MATRICULAS  ...  \
# 0                               4                      1            144  ...
# 1                               4                      1            184  ...
# 2                               4                      1            220  ...
# 3                               4                      1            186  ...
# 4                               4                      1             19  ...
# ...                           ...                    ...            ...  ...
# 172300                          2                      1            213  ...
# 172301                          2                      1            138  ...
# 172302                          2                      1            198  ...
# 172303                          4                      1             12  ...
# 172304                          4                      1             28  ...
#
#         NU_MEDIA_RED  NU_MEDIA_OBJ  NU_MEDIA_TOT     INSE  \
# 0                NaN           NaN         69.03     <NA>
# 1                NaN           NaN         57.82     <NA>
# 2                NaN           NaN         64.83     <NA>
# 3              72.16         60.02           NaN     <NA>
# 4                NaN           NaN         58.84     <NA>
# ...              ...           ...           ...      ...
# 172300        503.86           NaN           NaN     <NA>
# 172301        470.20           NaN           NaN     <NA>
# 172302        517.24           NaN           NaN  Grupo 3
# 172303        482.00           NaN           NaN     <NA>
# 172304        578.00           NaN           NaN  Grupo 5
#
#         PC_FORMACAO_DOCENTE  NU_TAXA_PERMANENCIA  NU_TAXA_APROVACAO  \
# 0                       NaN                  NaN               91.9
# 1                       NaN                  NaN                NaN
# 2                       NaN                  NaN               86.5
# 3                       NaN                  NaN               90.3
# 4                       NaN                  NaN               74.2
# ...                     ...                  ...                ...
# 172300                 91.8                  NaN               83.1
# 172301                 72.0                82.00               81.2
# 172302                 83.3                76.32               78.9
# 172303                 69.2                  NaN               91.4
# 172304                 57.1                75.00               95.0
#
#         NU_TAXA_REPROVACAO  NU_TAXA_ABANDONO         PORTE_ESCOLA
# 0                      8.1               0.0  Maior que 90 alunos
# 1                      NaN               NaN  Maior que 90 alunos
# 2                     12.4               1.1  Maior que 90 alunos
# 3                      9.7               0.0  Maior que 90 alunos
# 4                     21.0               4.8     De 1 a 30 alunos
# ...                    ...               ...                  ...
# 172300                 9.1               7.8  Maior que 90 alunos
# 172301                17.5               1.3  Maior que 90 alunos
# 172302                10.1              11.0  Maior que 90 alunos
# 172303                 8.6               0.0     De 1 a 30 alunos
# 172304                 5.0               0.0     De 1 a 30 alunos
#
# [172305 rows x 27 columns]

# %% [markdown]
# ## Preparação dos dados

# %%
df = df.drop(columns=['INSE', 'NU_MEDIA_OBJ', 'NU_MEDIA_TOT', 'PC_FORMACAO_DOCENTE', 
                      'NU_TAXA_PERMANENCIA', 'NU_PARTICIPANTES_NEC_ESP', 
                      'CO_UF_ESCOLA', 'NO_MUNICIPIO_ESCOLA', 'CO_ESCOLA_EDUCACENSO', 
                      'NO_ESCOLA_EDUCACENSO', 'NU_MATRICULAS', 'NU_TAXA_APROVACAO', 
                      'NU_TAXA_REPROVACAO', 'NU_TAXA_ABANDONO', 'CO_MUNICIPIO_ESCOLA'])

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# NU_ANO                        0.000000
# SG_UF_ESCOLA                  0.000000
# TP_DEPENDENCIA_ADM_ESCOLA     0.000000
# TP_LOCALIZACAO_ESCOLA         0.000000
# NU_PARTICIPANTES              0.000000
# NU_TAXA_PARTICIPACAO         39.243202
# NU_MEDIA_CN                  39.243202
# NU_MEDIA_CH                  39.243202
# NU_MEDIA_LP                  39.243202
# NU_MEDIA_MT                  39.243202
# NU_MEDIA_RED                 28.353211
# PORTE_ESCOLA                  0.000000
# dtype: float64

# %%
df = df.dropna()

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# NU_ANO                       0.0
# SG_UF_ESCOLA                 0.0
# TP_DEPENDENCIA_ADM_ESCOLA    0.0
# TP_LOCALIZACAO_ESCOLA        0.0
# NU_PARTICIPANTES             0.0
# NU_TAXA_PARTICIPACAO         0.0
# NU_MEDIA_CN                  0.0
# NU_MEDIA_CH                  0.0
# NU_MEDIA_LP                  0.0
# NU_MEDIA_MT                  0.0
# NU_MEDIA_RED                 0.0
# PORTE_ESCOLA                 0.0
# dtype: float64

# %%
df['NU_MEDIA_TOTAL'] = (df['NU_MEDIA_CN'] + df['NU_MEDIA_CH'] + df['NU_MEDIA_LP'] +
                        df['NU_MEDIA_MT'] + df['NU_MEDIA_RED'])/5

# %%
df.sort_values(by=['NU_MEDIA_TOTAL'], ascending=False, inplace=True)
df.head()
# Out:
#         NU_ANO SG_UF_ESCOLA  TP_DEPENDENCIA_ADM_ESCOLA  TP_LOCALIZACAO_ESCOLA  \
# 141940    2015           SP                          4                      1
# 170995    2014           GO                          4                      1
# 83322     2015           CE                          4                      1
# 141938    2013           SP                          4                      1
# 77207     2015           PI                          4                      1
#
#         NU_PARTICIPANTES  NU_TAXA_PARTICIPACAO  NU_MEDIA_CN  NU_MEDIA_CH  \
# 141940                41                100.00       728.80       721.47
# 170995                36                 90.00       731.12       713.91
# 83322                 35                100.00       715.13       704.89
# 141938                44                100.00       734.03       738.79
# 77207                124                 96.12       699.96       693.19
#
#         NU_MEDIA_LP  NU_MEDIA_MT  NU_MEDIA_RED         PORTE_ESCOLA  \
# 141940       681.23       873.65        813.17    De 31 a 60 alunos
# 170995       654.07       841.00        837.78    De 31 a 60 alunos
# 83322        663.21       851.45        841.14    De 31 a 60 alunos
# 141938       658.29       836.65        804.55    De 31 a 60 alunos
# 77207        645.35       832.80        897.42  Maior que 90 alunos
#
#         NU_MEDIA_TOTAL
# 141940         763.664
# 170995         755.576
# 83322          755.164
# 141938         754.462
# 77207          753.744

# %%
df['TP_RANKING'] = df.reset_index().drop(columns='index').index.to_numpy() < 1000
df['TP_RANKING'].replace({True:  '1%',
                          False: '99%'}, inplace=True)

# %%
df = df.sort_values(by='TP_RANKING')
df.head()
# Out:
#         NU_ANO SG_UF_ESCOLA  TP_DEPENDENCIA_ADM_ESCOLA  TP_LOCALIZACAO_ESCOLA  \
# 141940    2015           SP                          4                      1
# 120089    2012           RJ                          4                      1
# 138504    2010           SP                          4                      1
# 85284     2013           RN                          4                      1
# 118853    2013           RJ                          4                      1
#
#         NU_PARTICIPANTES  NU_TAXA_PARTICIPACAO  NU_MEDIA_CN  NU_MEDIA_CH  \
# 141940                41                100.00       728.80       721.47
# 120089                14                100.00       644.22       676.20
# 138504                18                100.00       643.63       684.95
# 85284                142                 94.67       632.39       668.86
# 118853                51                100.00       643.04       670.06
#
#         NU_MEDIA_LP  NU_MEDIA_MT  NU_MEDIA_RED         PORTE_ESCOLA  \
# 141940       681.23       873.65        813.17    De 31 a 60 alunos
# 120089       594.19       757.75        707.14     De 1 a 30 alunos
# 138504       624.79       739.82        686.11     De 1 a 30 alunos
# 85284        609.92       697.37        770.70  Maior que 90 alunos
# 118853       608.85       711.01        746.27    De 31 a 60 alunos
#
#         NU_MEDIA_TOTAL TP_RANKING
# 141940         763.664         1%
# 120089         675.900         1%
# 138504         675.860         1%
# 85284          675.848         1%
# 118853         675.846         1%

# %%
def subgrupo(x):
    if any((x =='PE', x =='PB', x =='RN', x =='AL', x =='SE', x =='CE', x =='BA', x =='MA', x =='PI')):
        return 'Nordeste'
    if any((x =='AC', x =='AM', x =='RO', x =='RR', x =='PA', x =='TO', x =='AP')):
        return 'Norte'
    if any((x =='MT', x =='GO', x =='MS', x =='DF')):
        return 'Centro-oeste'
    if any((x =='MG', x =='SP', x =='RJ', x =='ES')):
        return 'Sudeste'
    if any((x =='RS', x =='SC', x =='PR')):
        return 'Sul'

df['REGIAO_ESCOLA'] = df['SG_UF_ESCOLA'].apply(subgrupo)

# %%
df['TP_DEPENDENCIA_ADM_ESCOLA'].replace({1: 'Federal', 2: 'Estadual', 3: 'Municipal', 4: 'Privada'}, inplace=True)

# %%
df['TP_LOCALIZACAO_ESCOLA'].replace({1: 'Urbana', 2: 'Rural'}, inplace=True)

# %%
df
# Out:
#         NU_ANO SG_UF_ESCOLA TP_DEPENDENCIA_ADM_ESCOLA TP_LOCALIZACAO_ESCOLA  \
# 141940    2015           SP                   Privada                Urbana
# 120089    2012           RJ                   Privada                Urbana
# 138504    2010           SP                   Privada                Urbana
# 85284     2013           RN                   Privada                Urbana
# 118853    2013           RJ                   Privada                Urbana
# ...        ...          ...                       ...                   ...
# 171768    2013           DF                   Privada                Urbana
# 109856    2012           MG                   Privada                Urbana
# 70591     2013           RR                   Privada                Urbana
# 159037    2009           RS                  Estadual                Urbana
# 69107     2009           AM                  Estadual                 Rural
#
#         NU_PARTICIPANTES  NU_TAXA_PARTICIPACAO  NU_MEDIA_CN  NU_MEDIA_CH  \
# 141940                41                100.00       728.80       721.47
# 120089                14                100.00       644.22       676.20
# 138504                18                100.00       643.63       684.95
# 85284                142                 94.67       632.39       668.86
# 118853                51                100.00       643.04       670.06
# ...                  ...                   ...          ...          ...
# 171768                41                 75.93       500.25       541.23
# 109856                10                100.00       489.13       555.65
# 70591                 45                 90.00       502.42       536.70
# 159037                17                 58.60       496.25       512.63
# 69107                 40                 69.00       324.85       371.87
#
#         NU_MEDIA_LP  NU_MEDIA_MT  NU_MEDIA_RED  NU_MEDIA_TOTAL TP_RANKING  \
# 141940       681.23       873.65        813.17         763.664         1%
# 120089       594.19       757.75        707.14         675.900         1%
# 138504       624.79       739.82        686.11         675.860         1%
# 85284        609.92       697.37        770.70         675.848         1%
# 118853       608.85       711.01        746.27         675.846         1%
# ...             ...          ...           ...             ...        ...
# 171768       538.11       532.46        561.46         534.702        99%
# 109856       518.87       539.87        570.00         534.704        99%
# 70591        520.58       548.04        565.78         534.704        99%
# 159037       493.41       499.11        672.06         534.692        99%
# 69107        319.26       410.49        141.88         313.670        99%
#
#                PORTE_ESCOLA REGIAO_ESCOLA
# 141940    De 31 a 60 alunos       Sudeste
# 120089     De 1 a 30 alunos       Sudeste
# 138504     De 1 a 30 alunos       Sudeste
# 85284   Maior que 90 alunos      Nordeste
# 118853    De 31 a 60 alunos       Sudeste
# ...                     ...           ...
# 171768    De 31 a 60 alunos  Centro-oeste
# 109856     De 1 a 30 alunos       Sudeste
# 70591     De 31 a 60 alunos         Norte
# 159037     De 1 a 30 alunos           Sul
# 69107     De 31 a 60 alunos         Norte
#
# [104307 rows x 15 columns]

# %%
colunas = df.columns.tolist()
colunas[-4], colunas[-3] = colunas[-3], colunas[-4]
colunas[-3], colunas[-2] = colunas[-2], colunas[-3]
df = df[colunas]

df
# Out:
#         NU_ANO SG_UF_ESCOLA TP_DEPENDENCIA_ADM_ESCOLA TP_LOCALIZACAO_ESCOLA  \
# 141940    2015           SP                   Privada                Urbana
# 120089    2012           RJ                   Privada                Urbana
# 138504    2010           SP                   Privada                Urbana
# 85284     2013           RN                   Privada                Urbana
# 118853    2013           RJ                   Privada                Urbana
# ...        ...          ...                       ...                   ...
# 171768    2013           DF                   Privada                Urbana
# 109856    2012           MG                   Privada                Urbana
# 70591     2013           RR                   Privada                Urbana
# 159037    2009           RS                  Estadual                Urbana
# 69107     2009           AM                  Estadual                 Rural
#
#         NU_PARTICIPANTES  NU_TAXA_PARTICIPACAO  NU_MEDIA_CN  NU_MEDIA_CH  \
# 141940                41                100.00       728.80       721.47
# 120089                14                100.00       644.22       676.20
# 138504                18                100.00       643.63       684.95
# 85284                142                 94.67       632.39       668.86
# 118853                51                100.00       643.04       670.06
# ...                  ...                   ...          ...          ...
# 171768                41                 75.93       500.25       541.23
# 109856                10                100.00       489.13       555.65
# 70591                 45                 90.00       502.42       536.70
# 159037                17                 58.60       496.25       512.63
# 69107                 40                 69.00       324.85       371.87
#
#         NU_MEDIA_LP  NU_MEDIA_MT  NU_MEDIA_RED  NU_MEDIA_TOTAL TP_RANKING  \
# 141940       681.23       873.65        813.17         763.664         1%
# 120089       594.19       757.75        707.14         675.900         1%
# 138504       624.79       739.82        686.11         675.860         1%
# 85284        609.92       697.37        770.70         675.848         1%
# 118853       608.85       711.01        746.27         675.846         1%
# ...             ...          ...           ...             ...        ...
# 171768       538.11       532.46        561.46         534.702        99%
# 109856       518.87       539.87        570.00         534.704        99%
# 70591        520.58       548.04        565.78         534.704        99%
# 159037       493.41       499.11        672.06         534.692        99%
# 69107        319.26       410.49        141.88         313.670        99%
#
#                PORTE_ESCOLA REGIAO_ESCOLA
# 141940    De 31 a 60 alunos       Sudeste
# 120089     De 1 a 30 alunos       Sudeste
# 138504     De 1 a 30 alunos       Sudeste
# 85284   Maior que 90 alunos      Nordeste
# 118853    De 31 a 60 alunos       Sudeste
# ...                     ...           ...
# 171768    De 31 a 60 alunos  Centro-oeste
# 109856     De 1 a 30 alunos       Sudeste
# 70591     De 31 a 60 alunos         Norte
# 159037     De 1 a 30 alunos           Sul
# 69107     De 31 a 60 alunos         Norte
#
# [104307 rows x 15 columns]

# %% [markdown]
# ## Análise e visualização dos dados

# %%
fig, ax = plt.subplots(figsize=(20, 10))
sns.kdeplot(df.query("PORTE_ESCOLA == 'De 1 a 30 alunos'")['NU_MEDIA_TOTAL'], ax=ax, shade=True, label='De 1 a 30 alunos') 
sns.kdeplot(df.query("PORTE_ESCOLA == 'De 31 a 60 alunos'")['NU_MEDIA_TOTAL'], ax=ax, shade=True, label='De 31 a 60 alunos')
sns.kdeplot(df.query("PORTE_ESCOLA == 'De 61 a 90 alunos'")['NU_MEDIA_TOTAL'], ax=ax, shade=True, label='De 61 a 90 alunos') 
sns.kdeplot(df.query("PORTE_ESCOLA == 'Maior que 90 alunos'")['NU_MEDIA_TOTAL'], ax=ax, shade=True, label='Maior que 90 alunos') 
ax.set_title('Distribuição das notas de acordo com o porte da escola') # coloca titulo
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 10))
sns.kdeplot(df.query("TP_DEPENDENCIA_ADM_ESCOLA == 'Federal'")['NU_MEDIA_TOTAL'], ax=ax, shade=True, label='Federal') 
sns.kdeplot(df.query("TP_DEPENDENCIA_ADM_ESCOLA == 'Estadual'")['NU_MEDIA_TOTAL'], ax=ax, shade=True, label='Estadual')
sns.kdeplot(df.query("TP_DEPENDENCIA_ADM_ESCOLA == 'Municipal'")['NU_MEDIA_TOTAL'], ax=ax, shade=True, label='Municipal') 
sns.kdeplot(df.query("TP_DEPENDENCIA_ADM_ESCOLA == 'Privada'")['NU_MEDIA_TOTAL'], ax=ax, shade=True, label='Privada') 
ax.set_title('Distribuição das notas de acordo com o tipo de escola') # coloca titulo
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 10))
sns.kdeplot(df.query("TP_LOCALIZACAO_ESCOLA == 'Urbana'")['NU_MEDIA_TOTAL'], ax=ax, shade=True, label='Urbana') 
sns.kdeplot(df.query("TP_LOCALIZACAO_ESCOLA == 'Rural'")['NU_MEDIA_TOTAL'], ax=ax, shade=True, label='Rural')
ax.set_title('Distribuição das notas de acordo com o tipo de localização da escola') # coloca titulo
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 10))
sns.kdeplot(df.query("TP_DEPENDENCIA_ADM_ESCOLA == 'Federal'")['NU_TAXA_PARTICIPACAO'], ax=ax, shade=True, label='Federal') 
sns.kdeplot(df.query("TP_DEPENDENCIA_ADM_ESCOLA == 'Estadual'")['NU_TAXA_PARTICIPACAO'], ax=ax, shade=True, label='Estadual')
sns.kdeplot(df.query("TP_DEPENDENCIA_ADM_ESCOLA == 'Municipal'")['NU_TAXA_PARTICIPACAO'], ax=ax, shade=True, label='Municipal') 
sns.kdeplot(df.query("TP_DEPENDENCIA_ADM_ESCOLA == 'Privada'")['NU_TAXA_PARTICIPACAO'], ax=ax, shade=True, label='Privada') 
ax.set_title('Distribuição da taxa de participação de acordo com o tipo de escola') # coloca titulo
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 10))
sns.kdeplot(df.query("TP_LOCALIZACAO_ESCOLA == 'Urbana'")['NU_TAXA_PARTICIPACAO'], ax=ax, shade=True, label='Urbana') 
sns.kdeplot(df.query("TP_LOCALIZACAO_ESCOLA == 'Rural'")['NU_TAXA_PARTICIPACAO'], ax=ax, shade=True, label='Rural')
ax.set_title('Distribuição da taxa de participação de acordo com o tipo de localização da escola') # coloca titulo
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 10))
sns.barplot(data=df, x='NU_ANO', y='NU_TAXA_PARTICIPACAO', hue='TP_DEPENDENCIA_ADM_ESCOLA')
ax.set_title('Taxa de participação por tipo de escola de 2009 a 2015')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 10))
sns.barplot(data=df, x='NU_ANO', y='NU_PARTICIPANTES', hue='TP_DEPENDENCIA_ADM_ESCOLA', estimator=sum)
ax.set_title('Participantes por tipo de escola de 2009 a 2015')
plt.show()

# %%
sizes = []
labels = ['Federal', 'Estadual', 'Municipal', 'Privada']
for i in labels:
    sizes.append(df.query(f"TP_DEPENDENCIA_ADM_ESCOLA == '{i}'")['NU_PARTICIPANTES'].sum())

fig, ax = plt.subplots(figsize=(20, 10))
ax.pie(x=sizes, labels=labels, startangle=90, labeldistance=None)
ax.set_title('Participantes por tipo de escola de 2009 a 2015')
ax.axis('equal')
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(3, 2, figsize=(20, 15))
for i, area in enumerate(['NU_MEDIA_LP', 'NU_MEDIA_MT', 'NU_MEDIA_CH', 'NU_MEDIA_CN', 'NU_MEDIA_RED', 'NU_MEDIA_TOTAL']):
    sns.kdeplot(df.query("TP_DEPENDENCIA_ADM_ESCOLA == 'Federal'")[area], ax=ax[i//2, i%2], shade=True, label='Federal') 
    sns.kdeplot(df.query("TP_DEPENDENCIA_ADM_ESCOLA == 'Estadual'")[area], ax=ax[i//2, i%2], shade=True, label='Estadual')
    sns.kdeplot(df.query("TP_DEPENDENCIA_ADM_ESCOLA == 'Municipal'")[area], ax=ax[i//2, i%2], shade=True, label='Municipal') 
    sns.kdeplot(df.query("TP_DEPENDENCIA_ADM_ESCOLA == 'Privada'")[area], ax=ax[i//2, i%2], shade=True, label='Privada')  
    ax[i//2, i%2].legend()
plt.show()

# %%
def compare_distribution(column, chart_title, legend_title):
    fig, ax = plt.subplots(figsize=(15, 3)) 
    # Define o título do gráfico e cria o gráfico
    ax.set_title(chart_title) 
    sns.histplot(df, y="TP_RANKING", hue=column, stat="probability", multiple="fill", shrink=0.8, ax=ax, edgecolor="none")
    
    # Remove as linhas dos eixos
    sns.despine(left=True, bottom=True)
    
    # Remove o titulo do eixo vertical e define o do eixo horizontal
    ax.set_ylabel('') 
    ax.set_xlabel('Proporção') 
    
    # Muda a legenda de posição
    legends = re.findall(r"'(.*?)'", str(list(ax.get_legend().get_texts())))
    legends.reverse()
    plt.legend(legends, title=legend_title,bbox_to_anchor=(0.5,-0.2), loc='upper center', ncol=3)
    plt.show()

# %%
compare_distribution('TP_DEPENDENCIA_ADM_ESCOLA', 'Distribuição dos tipos de escola entre as melhores notas e entre o restante', 'Tipos de escola')

# %%
compare_distribution('TP_LOCALIZACAO_ESCOLA', 'Distribuição dos tipos de localização das escolas entre as melhores notas e entre o restante', 'Tipo de localização da escola')

# %%
compare_distribution('REGIAO_ESCOLA', 'Distribuição das regiões das escolas entre as melhores notas e entre o restante', 'Região da escola')
